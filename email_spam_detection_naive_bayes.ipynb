# %% [markdown]
# <a href="https://colab.research.google.com/github/vinakandekar05/AI-Based-cyber-crime-Detection/blob/main/email_spam_detection_naive_bayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
df=pd.read_csv("/content/email_spam_naive_bayes.csv")

# %%
df.head()
# Out:
#    free  win  offer  money  click  is_spam
# 0     4    0      1      0      1        0
# 1     4    2      2      0      0        0
# 2     2    0      4      2      0        0
# 3     3    2      3      3      1        1
# 4     1    1      4      0      2        0

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
X = df[['free', 'win', 'offer', 'money', 'click']]
y = df['is_spam']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.25, random_state=42
)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.5238095238095238

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.83      0.66        35
#            1       0.40      0.14      0.21        28
#
#     accuracy                           0.52        63
#    macro avg       0.47      0.49      0.43        63
# weighted avg       0.48      0.52      0.46        63

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Spam Detection - Confusion Matrix")
plt.show()

# %%
new_email = "Congratulations you won a free prize"
new_email_vec = [[1, 1, 0, 0, 0]]

prediction = model.predict(ew_email_vec)

if prediction[0] == 1:
    print(f"Spam Email 🚨: '{ew_email}'")
else:
    print(f"Not Spam ✅: '{ew_email}'")
# Out:
# Not Spam ✅: 'Congratulations you won a free prize'
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but MultinomialNB was fitted with feature names
#   warnings.warn(
